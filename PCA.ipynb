# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data=pd.read_csv('glass (1) (1).data')

# %%
data
# Out:
#      index       RI     Na    Mg    Al     Si     K    Ca    Ba   Fe  Class
# 0        1  1.52101  13.64  4.49  1.10  71.78  0.06  8.75  0.00  0.0      1
# 1        2  1.51761  13.89  3.60  1.36  72.73  0.48  7.83  0.00  0.0      1
# 2        3  1.51618  13.53  3.55  1.54  72.99  0.39  7.78  0.00  0.0      1
# 3        4  1.51766  13.21  3.69  1.29  72.61  0.57  8.22  0.00  0.0      1
# 4        5  1.51742  13.27  3.62  1.24  73.08  0.55  8.07  0.00  0.0      1
# ..     ...      ...    ...   ...   ...    ...   ...   ...   ...  ...    ...
# 209    210  1.51623  14.14  0.00  2.88  72.61  0.08  9.18  1.06  0.0      7
# 210    211  1.51685  14.92  0.00  1.99  73.06  0.00  8.40  1.59  0.0      7
# 211    212  1.52065  14.36  0.00  2.02  73.42  0.00  8.44  1.64  0.0      7
# 212    213  1.51651  14.38  0.00  1.94  73.61  0.00  8.48  1.57  0.0      7
# 213    214  1.51711  14.23  0.00  2.08  73.36  0.00  8.62  1.67  0.0      7
#
# [214 rows x 11 columns]

# %%
data.shape
# Out:
# (214, 11)

# %%
data.head()
# Out:
#    index       RI     Na    Mg    Al     Si     K    Ca   Ba   Fe  Class
# 0      1  1.52101  13.64  4.49  1.10  71.78  0.06  8.75  0.0  0.0      1
# 1      2  1.51761  13.89  3.60  1.36  72.73  0.48  7.83  0.0  0.0      1
# 2      3  1.51618  13.53  3.55  1.54  72.99  0.39  7.78  0.0  0.0      1
# 3      4  1.51766  13.21  3.69  1.29  72.61  0.57  8.22  0.0  0.0      1
# 4      5  1.51742  13.27  3.62  1.24  73.08  0.55  8.07  0.0  0.0      1

# %%
data.tail()
# Out:
#      index       RI     Na   Mg    Al     Si     K    Ca    Ba   Fe  Class
# 209    210  1.51623  14.14  0.0  2.88  72.61  0.08  9.18  1.06  0.0      7
# 210    211  1.51685  14.92  0.0  1.99  73.06  0.00  8.40  1.59  0.0      7
# 211    212  1.52065  14.36  0.0  2.02  73.42  0.00  8.44  1.64  0.0      7
# 212    213  1.51651  14.38  0.0  1.94  73.61  0.00  8.48  1.57  0.0      7
# 213    214  1.51711  14.23  0.0  2.08  73.36  0.00  8.62  1.67  0.0      7

# %%
data['Class'].value_counts()
# Out:
# Class
# 2    76
# 1    70
# 7    29
# 3    17
# 5    13
# 6     9
# Name: count, dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 214 entries, 0 to 213
# Data columns (total 11 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   index   214 non-null    int64
#  1   RI      214 non-null    float64
#  2   Na      214 non-null    float64
#  3   Mg      214 non-null    float64
#  4   Al      214 non-null    float64
#  5   Si      214 non-null    float64
#  6   K       214 non-null    float64
#  7   Ca      214 non-null    float64
#  8   Ba      214 non-null    float64
#  9   Fe      214 non-null    float64
#  10  Class   214 non-null    int64
# dtypes: float64(9), int64(2)
# memory usage: 18.5 KB

# %%
data.describe()
# Out:
#             index          RI          Na          Mg          Al          Si  \
# count  214.000000  214.000000  214.000000  214.000000  214.000000  214.000000
# mean   107.500000    1.518365   13.407850    2.684533    1.444907   72.650935
# std     61.920648    0.003037    0.816604    1.442408    0.499270    0.774546
# min      1.000000    1.511150   10.730000    0.000000    0.290000   69.810000
# 25%     54.250000    1.516522   12.907500    2.115000    1.190000   72.280000
# 50%    107.500000    1.517680   13.300000    3.480000    1.360000   72.790000
# 75%    160.750000    1.519157   13.825000    3.600000    1.630000   73.087500
# max    214.000000    1.533930   17.380000    4.490000    3.500000   75.410000
#
#                 K          Ca          Ba          Fe       Class
# count  214.000000  214.000000  214.000000  214.000000  214.000000
# mean     0.497056    8.956963    0.175047    0.057009    2.780374
# std      0.652192    1.423153    0.497219    0.097439    2.103739
# ...

# %%
data.drop('index',axis=1, inplace=True)

# %%
data.head()
# Out:
#         RI     Na    Mg    Al     Si     K    Ca   Ba   Fe  Class
# 0  1.52101  13.64  4.49  1.10  71.78  0.06  8.75  0.0  0.0      1
# 1  1.51761  13.89  3.60  1.36  72.73  0.48  7.83  0.0  0.0      1
# 2  1.51618  13.53  3.55  1.54  72.99  0.39  7.78  0.0  0.0      1
# 3  1.51766  13.21  3.69  1.29  72.61  0.57  8.22  0.0  0.0      1
# 4  1.51742  13.27  3.62  1.24  73.08  0.55  8.07  0.0  0.0      1

# %%
data.Class.unique()
# Out:
# array([1, 2, 3, 5, 6, 7], dtype=int64)

# %% [markdown]
# ## data Processing

# %%
data.isnull().sum()
# Out:
# RI       0
# Na       0
# Mg       0
# Al       0
# Si       0
# K        0
# Ca       0
# Ba       0
# Fe       0
# Class    0
# dtype: int64

# %%
data.duplicated().sum()
# Out:
# 1

# %%
data = data.drop_duplicates()

# %%
data.head()
# Out:
#         RI     Na    Mg    Al     Si     K    Ca   Ba   Fe  Class
# 0  1.52101  13.64  4.49  1.10  71.78  0.06  8.75  0.0  0.0      1
# 1  1.51761  13.89  3.60  1.36  72.73  0.48  7.83  0.0  0.0      1
# 2  1.51618  13.53  3.55  1.54  72.99  0.39  7.78  0.0  0.0      1
# 3  1.51766  13.21  3.69  1.29  72.61  0.57  8.22  0.0  0.0      1
# 4  1.51742  13.27  3.62  1.24  73.08  0.55  8.07  0.0  0.0      1

# %%
df=data.drop(columns='Class',axis=1)

# %%
df.head(3)
# Out:
#         RI     Na    Mg    Al     Si     K    Ca   Ba   Fe
# 0  1.52101  13.64  4.49  1.10  71.78  0.06  8.75  0.0  0.0
# 1  1.51761  13.89  3.60  1.36  72.73  0.48  7.83  0.0  0.0
# 2  1.51618  13.53  3.55  1.54  72.99  0.39  7.78  0.0  0.0

# %%
## getting the optimal number of pca
from sklearn.decomposition import PCA
pca=PCA()
principleComponents=pca.fit_transform(df)

# %%
principleComponents
# Out:
# array([[ 1.43019680e+00,  1.10115572e+00, -1.05999338e+00, ...,
#         -6.87655825e-02, -1.08296149e-02,  9.42986285e-04],
#        [ 1.43871254e+00, -3.38951080e-01, -2.47205562e-01, ...,
#         -4.36700640e-02,  1.73373741e-02,  9.54218671e-04],
#        [ 1.42992246e+00, -3.37221258e-01,  1.67855039e-01, ...,
#         -4.54711816e-02, -1.95648694e-02,  3.50650910e-04],
#        ...,
#        [-1.77239750e+00, -2.72919432e+00,  1.00874173e-01, ...,
#         -2.62606395e-02, -1.27435558e-02,  3.71222495e-03],
#        [-1.78939074e+00, -2.71266124e+00,  2.37478745e-01, ...,
#         -2.96388188e-02,  2.49604381e-02, -4.01436737e-04],
#        [-1.89819142e+00, -2.57651116e+00,  1.17671003e-01, ...,
#         -3.78458027e-02,  1.79865719e-02, -2.88898877e-04]])

# %%
plt.figure()
plt.plot(np.cumsum(pca.explained_variance_ratio_))

plt.xlabel('Number of Components')
plt.ylabel('Variance (%)') #for each component
plt.title('Explained Variance')
plt.show()

# %%
#From the diagram above, it can be seen that 3 principal components explain almost 95% of the variance in data

#So, instead of giving all the columns as input, we’d only feed these 3 principal components of the data to the machine learning algorithm and we’d obtain a similar result.

# %%
pca=PCA(n_components=3)
new_data=pca.fit_transform(df)
new_data
# Out:
# array([[ 1.43019680e+00,  1.10115572e+00, -1.05999338e+00],
#        [ 1.43871254e+00, -3.38951080e-01, -2.47205562e-01],
#        [ 1.42992246e+00, -3.37221258e-01,  1.67855039e-01],
#        [ 1.25939242e+00,  2.57125066e-01,  4.49670228e-02],
#        [ 1.31462723e+00,  2.80301480e-02,  3.79486907e-01],
#        [ 1.30450759e+00,  1.36206425e-01,  6.10902134e-01],
#        [ 1.23855649e+00,  8.71378365e-02,  3.66027349e-01],
#        [ 1.20534351e+00,  1.91991099e-01,  5.60201543e-01],
#        [ 1.10188280e+00, -8.83524019e-03, -8.49941983e-01],
#        [ 1.07548889e+00,  3.15767447e-01,  4.58605903e-01],
#        [ 1.19083724e+00,  6.36848179e-02,  8.47082516e-01],
#        [ 1.02013367e+00,  5.42163324e-01,  5.77142050e-01],
#        [ 1.20311821e+00, -1.83566628e-02,  8.16842684e-01],
#        [ 1.06622846e+00,  3.23831632e-01,  7.10014014e-01],
#        [ 1.01276540e+00,  4.82882700e-01,  9.14782370e-01],
#        [ 1.05122915e+00,  3.36982064e-01,  7.68777369e-01],
# ...

# %%
principal_df=pd.DataFrame(data=new_data
                         ,columns=['Pc1','pc2','pc3'])

# %%
principal_df.head()
x=principal_df
y=data['Class']

# %%
x
# Out:
#           Pc1       pc2       pc3
# 0    1.430197  1.101156 -1.059993
# 1    1.438713 -0.338951 -0.247206
# 2    1.429922 -0.337221  0.167855
# 3    1.259392  0.257125  0.044967
# 4    1.314627  0.028030  0.379487
# ..        ...       ...       ...
# 208 -2.267970 -2.129365 -0.320386
# 209 -1.752929 -2.893603 -0.500494
# 210 -1.772398 -2.729194  0.100874
# 211 -1.789391 -2.712661  0.237479
# 212 -1.898191 -2.576511  0.117671
#
# [213 rows x 3 columns]

# %%
y
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 209    7
# 210    7
# 211    7
# 212    7
# 213    7
# Name: Class, Length: 213, dtype: int64

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.25,random_state=10)

# %%
x.shape
# Out:
# (213, 3)

# %%
x_train.shape
# Out:
# (159, 3)

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression()
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=model.predict(x_test)

# %%
y_pred
# Out:
# array([6.90578958, 4.37114976, 2.03800232, 2.08255161, 2.03543948,
#        1.23175412, 1.91164416, 2.04690331, 1.23929473, 1.25552928,
#        1.53044867, 7.17376891, 2.42759366, 2.39822127, 5.26532618,
#        6.43632897, 1.9540367 , 1.01920393, 1.95655591, 1.73625993,
#        2.01737529, 1.94743764, 1.98719311, 1.83036824, 1.88306587,
#        1.3603219 , 2.14299839, 1.9100481 , 3.12668363, 1.81297464,
#        1.74546428, 2.08404589, 3.1598738 , 1.85999059, 3.6315755 ,
#        2.31290321, 2.46906944, 2.39979662, 2.02236773, 5.54788322,
#        1.96554833, 1.99568456, 1.87675365, 1.69558342, 5.06624558,
#        2.07357076, 1.90775707, 2.38502152, 3.62229477, 1.86249356,
#        6.83515901, 1.35353058, 3.68833483, 1.6203653 ])

# %%
y_test
# Out:
# 212    7
# 186    7
# 26     1
# 79     2
# 88     2
# 69     1
# 60     1
# 24     1
# 50     1
# 62     1
# 47     1
# 200    7
# 53     1
# 107    2
# 183    6
# 171    5
# 148    3
# 48     1
# 19     1
# 115    2
# 35     1
# 59     1
# 77     2
# 57     1
# 137    2
# 64     1
# 92     2
# 161    3
# 70     2
# 162    3
# 20     1
# 160    3
# 112    2
# 5      1
# 179    6
# 61     1
# 1      1
# 2      1
# 121    2
# 182    6
# 10     1
# 6      1
# 56     1
# 125    2
# 168    5
# 104    2
# 133    2
# 99     2
# 84     2
# 7      1
# 213    7
# 103    2
# 106    2
# 40     1
# Name: Class, dtype: int64

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

# %%
mse=mean_squared_error(y_test,y_pred)
mse
# Out:
# 0.9091534843816985

# %%
mae = mean_absolute_error(y_test,y_pred)
mae
# Out:
# 0.7491263962497322

# %%
rmse = np.sqrt(mse)
rmse
# Out:
# 0.9534954034402571

# %%
r2_score(y_test,y_pred)
# Out:
# 0.7388601693797249

# %%
## without pca

# %%
x1=data.drop(columns='Class',axis=1)
y1=data['Class']

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x1,y1,test_size=0.25,random_state=10)

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression()
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred1=model.predict(x_test)

# %%
y_pred1
# Out:
# array([7.07141852, 4.95581765, 2.15069595, 2.49753526, 2.06705526,
#        1.33334338, 1.96703624, 1.93397947, 0.8371641 , 1.11571811,
#        1.5706751 , 7.16867372, 2.38457739, 2.42812484, 4.23829808,
#        5.55299541, 1.89278632, 1.09205094, 2.29076764, 1.87254788,
#        1.81618436, 1.78369224, 2.08098599, 1.90201203, 2.16393304,
#        1.34517532, 2.18504989, 1.36297194, 2.93297982, 1.16250486,
#        1.70457975, 2.28797729, 2.93450251, 1.74700011, 3.80551401,
#        2.57214053, 2.52104932, 2.53191602, 1.99868539, 5.68873113,
#        1.81407841, 1.96132054, 0.89086018, 1.90843369, 4.88344789,
#        2.26451971, 1.85628935, 2.53513229, 3.65815397, 1.80144175,
#        7.15971286, 1.35883094, 4.87655172, 1.63423566])

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

# %%
mse=mean_squared_error(y_test,y_pred1)
mse
# Out:
# 1.012754923859862

# %%
mae = mean_absolute_error(y_test,y_pred1)
mae
# Out:
# 0.7694469325342583

# %%
rmse = np.sqrt(mse)
rmse
# Out:
# 1.0063572545869892

# %%
r2_score(y_test,y_pred1)
# Out:
# 0.7091023091040821

# %% [markdown]
# ## so with pca the model performance is 73% and without pca it is 70%
